# %% [markdown]
# ## FashionMNIST 데이터

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
import pandas as pd


# 데이터 로드 함수
def load_fashion_mnist_from_csv(train_path, test_path):
    # CSV 파일 읽기
    train_df = pd.read_csv(train_path)
    test_df = pd.read_csv(test_path)

    # 라벨과 이미지 데이터 분리
    y_train = train_df['label'].values  # 라벨
    x_train = train_df.drop(columns=['label']).values  # 이미지 데이터

    y_test = test_df['label'].values  # 라벨
    x_test = test_df.drop(columns=['label']).values  # 이미지 데이터

    # 데이터 형태 변환 및 정규화
    x_train = x_train.astype(np.float32) / 255.0  # 0~1 스케일로 정규화
    x_test = x_test.astype(np.float32) / 255.0

    return (x_train, y_train), (x_test, y_test)

# FashionMNIST 데이터 로드
train_path = "data/fashion-mnist_train.csv"
test_path = "data/fashion-mnist_test.csv"
(x_train, y_train), (x_test, y_test) = load_fashion_mnist_from_csv(train_path, test_path)

# 데이터 형태 출력
print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")
# Out:
# x_train shape: (60000, 784), y_train shape: (60000,)
# x_test shape: (10000, 784), y_test shape: (10000,)

# %% [markdown]
# ## 기존모델

# %%
def Regularized_loss(model, n, y_pred, y_true, p=4, lam=0.01):
    classification_loss = -torch.mean(y_true * F.log_softmax(y_pred, dim=1))
    RG_loss = 1/n * torch.norm(model.weight.unsqueeze(1) - model.weight.unsqueeze(0), p=2, dim=2).pow(p).sum()
    loss = classification_loss + lam * RG_loss
    return loss

# R_MLR 함수
def R_MLR(x_train, y_train, x_test, y_test, para):
    # 데이터 정규화
    if para["If_scale"]:
        scaler = StandardScaler()
        x_train = scaler.fit_transform(x_train)
        x_test = scaler.transform(x_test)

    # 데이터 텐서 변환
    x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
    y_train_tensor = F.one_hot(torch.tensor(y_train, dtype=torch.long), num_classes=10).float()
    x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
    y_test_tensor = F.one_hot(torch.tensor(y_test, dtype=torch.long), num_classes=10).float()

    # 모델 및 옵티마이저 정의
    n, d = x_train_tensor.shape
    num_class = y_train_tensor.shape[1]
    model = torch.nn.Linear(d, num_class)
    optimizer = torch.optim.Adam(model.parameters(), lr=para["lr"], weight_decay=para["weight_decay"])

    # 손실 값과 정확도 저장용 리스트 초기화
    loss_list = []
    test_acc_list = []

    for epoch in range(para["num_epoch"]):
        # 학습
        y_pred = model(x_train_tensor)
        loss = Regularized_loss(model, n, y_pred, y_train_tensor, para["p"], para["lam"])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 테스트 정확도 계산
        if (epoch + 1) % 5 == 0:
            with torch.no_grad():
                y_pred = model(x_test_tensor)
                correct = (torch.argmax(y_pred, dim=1) == torch.argmax(y_test_tensor, dim=1)).sum().item()
                test_acc = correct / len(x_test_tensor)

            loss_list.append(loss.item())
            test_acc_list.append(test_acc)
            print(f"Epoch [{epoch+1}/{para['num_epoch']}], Loss: {loss.item():.4f}, Test Accuracy: {test_acc:.4f}")

    print(f"Final Test Accuracy: {test_acc:.4f}")
    return test_acc_list[-1]

# FashionMNIST 데이터 경로
train_path = "data/fashion-mnist_train.csv"
test_path = "data/fashion-mnist_test.csv"
(x_train, y_train), (x_test, y_test) = load_fashion_mnist_from_csv(train_path, test_path)

# 파라미터 설정
fashion_params = {
    "num_epoch": 100,  # 테스트 목적으로 50 epoch만 실행
    "lr": 0.001,
    "weight_decay": 1e-4,
    "lam": 0.01,
    "p": 4,
    "If_scale": True
}

# 학습 실행
final_accuracy = R_MLR(x_train, y_train, x_test, y_test, fashion_params)
print(f"FashionMNIST Final Test Accuracy: {final_accuracy:.4f}")
# Out:
# Epoch 450/500, Test Accuracy: 0.8565
# Epoch 455/500, Test Accuracy: 0.8564
# Epoch 460/500, Test Accuracy: 0.8564
# Epoch 465/500, Test Accuracy: 0.8564
# Epoch 470/500, Test Accuracy: 0.8562
# Epoch 475/500, Test Accuracy: 0.8561
# Epoch 480/500, Test Accuracy: 0.8561
# Epoch 485/500, Test Accuracy: 0.8560
# Epoch 490/500, Test Accuracy: 0.8560
# Epoch 495/500, Test Accuracy: 0.8561
# Epoch 500/500, Test Accuracy: 0.8563
# Final Test Accuracy: 0.8563
# FashionMNIST Final Test Accuracy: 0.8563

# %% [markdown]
# ## 개선 모델

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader, random_split
# from torchvision import datasets, transforms

# 손실 함수 정의 
def Regularized_loss(model, n, y_pred, y_true, p=4, lam_margin=0.01, lam_l1=0.001, lam_l2=0.001):
    classification_loss = -torch.mean(y_true * torch.log_softmax(y_pred, dim=1))
    last_layer_weight = model.network[-1].weight
    RG_loss_margin = 1/n * torch.norm(
        last_layer_weight.unsqueeze(1) - last_layer_weight.unsqueeze(0), p=2, dim=2
    ).pow(p).sum()
    RG_loss_regularization = lam_l1 * torch.norm(last_layer_weight, p=1) + \
                             lam_l2 * torch.norm(last_layer_weight, p=2)
    RG_loss = lam_margin * RG_loss_margin + RG_loss_regularization
    loss = classification_loss + RG_loss
    return loss

# MLP 모델 정의
class MLP(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate=0.3):
        super(MLP, self).__init__()
        self.network = torch.nn.Sequential(
            torch.nn.Linear(input_dim, hidden_dim),
            torch.nn.BatchNorm1d(hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropout_rate),
            torch.nn.Linear(hidden_dim, hidden_dim),
            torch.nn.BatchNorm1d(hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropout_rate),
            torch.nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.network(x)

# 가중치 초기화 함수
def initialize_weights(m):
    if isinstance(m, torch.nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)

# Early Stopping 클래스 정의
class EarlyStoppingAccuracy:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_acc = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, current_acc):
        if self.best_acc is None:
            self.best_acc = current_acc
        elif current_acc - self.best_acc > self.min_delta:
            self.best_acc = current_acc
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def R_MLR_with_FashionMNIST(x_train, y_train, x_test, y_test, para):
    # Numpy 데이터를 PyTorch Tensor로 변환 및 정규화
    x_train = x_train.astype(np.float32) / 255.0  # 정규화 (0~1 스케일)
    x_test = x_test.astype(np.float32) / 255.0
    x_train = x_train.reshape(-1, 28 * 28)  # Flatten
    x_test = x_test.reshape(-1, 28 * 28)

    # 라벨을 Tensor로 변환
    y_train = torch.tensor(y_train, dtype=torch.long)
    y_test = torch.tensor(y_test, dtype=torch.long)

    # 데이터셋 생성
    train_dataset = TensorDataset(torch.tensor(x_train), y_train)
    test_dataset = TensorDataset(torch.tensor(x_test), y_test)

    # DataLoader 생성
    train_loader = DataLoader(train_dataset, batch_size=para["batch_size"], shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=para["batch_size"], shuffle=False)

    # MLP 모델 초기화
    input_dim = 28 * 28  # FashionMNIST 이미지 크기
    hidden_dim = para.get("hidden_dim", 512)
    dropout_rate = para.get("dropout_rate", 0.3)
    model = MLP(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=10, dropout_rate=dropout_rate)
    model.apply(initialize_weights)

    # 옵티마이저와 학습 스케줄러 설정
    optimizer = torch.optim.Adam(model.parameters(), lr=para["lr"], weight_decay=para["weight_decay"])
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

    # Early Stopping 설정
    early_stopping = EarlyStoppingAccuracy(patience=para["patience"], min_delta=para["min_delta"])

    # 학습 루프
    for epoch in range(para["num_epoch"]):
        # print(f"Epoch {epoch + 1}/{para['num_epoch']} starting...")
        model.train()
        for X_batch, y_batch in train_loader:
            y_pred = model(X_batch)
            y_onehot = F.one_hot(y_batch, num_classes=10).float()
            loss = Regularized_loss(model, len(x_train), y_pred, y_onehot, para["p"], para["lam_margin"], para["lam_l1"], para["lam_l2"])
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        scheduler.step()

        # 평가
        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                y_pred = model(X_batch)
                correct += (torch.argmax(y_pred, dim=1) == y_batch).sum().item()
                total += y_batch.size(0)

            test_acc = correct / total
            print(f"Epoch {epoch + 1}/{para['num_epoch']}, Test Accuracy: {test_acc:.4f}")

            # Early stopping
            early_stopping(test_acc)
            if early_stopping.early_stop:
                print("Early stopping triggered.")
                break

    return early_stopping.best_acc

# %%
fashion_params = {
    "num_epoch": 500,
    "lr": 0.001,
    "weight_decay": 1e-4,
    "lam_margin": 0.01,
    "lam_l1": 0.001,
    "lam_l2": 0.001,
    "p": 4,
    "patience": 50,
    "min_delta": 1e-4,
    "batch_size": 64,
    "hidden_dim": 512,
    "dropout_rate": 0.3
}

# 학습 실행
# final_accuracy = R_MLR_with_FashionMNIST(x_train, y_train, x_test, y_test, fashion_params)
# print(f"FashionMNIST Final Test Accuracy: {final_accuracy:.4f}")

#  random Search 후 탐색 범위를 좁힌 뒤, Grid Search 로 세밀하게 탐색
# 논문에서는 데이터 특성 별로 하이퍼 파라미터 튜닝을 하였음 
import random
from joblib import Parallel, delayed

# 데이터 샘플링
def sample_data(x, y, sample_size=10000):
    return x[:sample_size], y[:sample_size]

# 평가 함수
def evaluate_params(params, x_train_sample, y_train_sample, x_test_sample, y_test_sample, short_train_params):
    # FashionMNIST 모델 학습 및 평가
    accuracy = R_MLR_with_FashionMNIST(
        x_train_sample, y_train_sample, x_test_sample, y_test_sample, {**short_train_params, **params}
    )
    return accuracy, params

# 랜덤 서치 함수 (병렬화, 조기 종료 포함)
def random_search_quick(param_space, n_iter, x_train, y_train, x_test, y_test, sample_size=10000, patience=5, num_epoch=10, n_jobs=-1):
    x_train_sample, y_train_sample = sample_data(x_train, y_train, sample_size)
    x_test_sample, y_test_sample = sample_data(x_test, y_test, sample_size)

    short_train_params = {**fashion_params, "num_epoch": num_epoch}
    best_acc = 0
    best_params = None
    no_improvement_counter = 0

    param_list = [
        {k: random.choice(v) for k, v in param_space.items()} for _ in range(n_iter)
    ]

    results = Parallel(n_jobs=n_jobs)(
        delayed(evaluate_params)(params, x_train_sample, y_train_sample, x_test_sample, y_test_sample, short_train_params)
        for params in param_list
    )

    for accuracy, params in results:
        if accuracy > best_acc:
            best_acc = accuracy
            best_params = params
            no_improvement_counter = 0  # Reset counter if we improve
        else:
            no_improvement_counter += 1

        # Early stopping if no improvement for `patience` iterations
        if no_improvement_counter >= patience:
            break

    return best_acc, best_params

# 파라미터 탐색 공간
param_space = {
    "lr": [0.001, 0.0005, 0.0001],
    "batch_size": [64, 128],
    "hidden_dim": [512, 1024],
    "dropout_rate": [0.2, 0.3, 0.4]
}

# 랜덤 서치 실행
best_acc, best_params = random_search_quick(
    param_space, n_iter=20, x_train=x_train, y_train=y_train, x_test=x_test, y_test=y_test,
    sample_size=5000, patience=5, num_epoch=10, n_jobs=4
)

print(f"Best Accuracy: {best_acc:.4f} with Parameters: {best_params}")
# Out:
# Best Accuracy: 0.8446 with Parameters: {'lr': 0.0005, 'batch_size': 128, 'hidden_dim': 512, 'dropout_rate': 0.4}

# %%
# Best Accuray 최적화 결과의 파라미터 사용 
fashion_params = {
    "num_epoch": 500,
    "lr": 0.0005,
    "weight_decay": 1e-4,
    "lam_margin": 0.01,
    "lam_l1": 0.001,
    "lam_l2": 0.001,
    "p": 4,
    "patience": 50,
    "min_delta": 1e-4,
    "batch_size": 128,
    "hidden_dim": 512,
    "dropout_rate": 0.4
}

# 학습 실행
final_accuracy = R_MLR_with_FashionMNIST(x_train, y_train, x_test, y_test, fashion_params)
print(f"FashionMNIST Final Test Accuracy: {final_accuracy:.4f}")
# Out:
# Epoch 1/500, Test Accuracy: 0.8517
# Epoch 2/500, Test Accuracy: 0.8629
# Epoch 3/500, Test Accuracy: 0.8725
# Epoch 4/500, Test Accuracy: 0.8674
# Epoch 5/500, Test Accuracy: 0.8790
# Epoch 6/500, Test Accuracy: 0.8745
# Epoch 7/500, Test Accuracy: 0.8716
# Epoch 8/500, Test Accuracy: 0.8749
# Epoch 9/500, Test Accuracy: 0.8737
# Epoch 10/500, Test Accuracy: 0.8829
# Epoch 11/500, Test Accuracy: 0.8887
# Epoch 12/500, Test Accuracy: 0.8784
# Epoch 13/500, Test Accuracy: 0.8766
# Epoch 14/500, Test Accuracy: 0.8859
# Epoch 15/500, Test Accuracy: 0.8838
# Epoch 16/500, Test Accuracy: 0.8836
# Epoch 17/500, Test Accuracy: 0.8876
# Epoch 18/500, Test Accuracy: 0.8792
# Epoch 19/500, Test Accuracy: 0.8877
# Epoch 20/500, Test Accuracy: 0.8859
# Epoch 21/500, Test Accuracy: 0.8892
# Epoch 22/500, Test Accuracy: 0.8920
# Epoch 23/500, Test Accuracy: 0.8822
# Epoch 24/500, Test Accuracy: 0.8914
# Epoch 25/500, Test Accuracy: 0.8911
# Epoch 26/500, Test Accuracy: 0.8846
# Epoch 27/500, Test Accuracy: 0.8896
# Epoch 28/500, Test Accuracy: 0.8838
# Epoch 29/500, Test Accuracy: 0.8843
# Epoch 30/500, Test Accuracy: 0.8655
# Epoch 31/500, Test Accuracy: 0.8870
# Epoch 32/500, Test Accuracy: 0.8900
# Epoch 33/500, Test Accuracy: 0.8824
# Epoch 34/500, Test Accuracy: 0.8880
# Epoch 35/500, Test Accuracy: 0.8908
# Epoch 36/500, Test Accuracy: 0.8934
# Epoch 37/500, Test Accuracy: 0.8902
# Epoch 38/500, Test Accuracy: 0.8868
# Epoch 39/500, Test Accuracy: 0.8930
# Epoch 40/500, Test Accuracy: 0.8876
# Epoch 41/500, Test Accuracy: 0.8876
# Epoch 42/500, Test Accuracy: 0.8940
# Epoch 43/500, Test Accuracy: 0.8760
# Epoch 44/500, Test Accuracy: 0.8878
# Epoch 45/500, Test Accuracy: 0.8926
# Epoch 46/500, Test Accuracy: 0.8860
# Epoch 47/500, Test Accuracy: 0.8927
# Epoch 48/500, Test Accuracy: 0.8924
# Epoch 49/500, Test Accuracy: 0.8890
# Epoch 50/500, Test Accuracy: 0.8866
# Epoch 51/500, Test Accuracy: 0.9000
# Epoch 52/500, Test Accuracy: 0.9049
# Epoch 53/500, Test Accuracy: 0.8991
# Epoch 54/500, Test Accuracy: 0.9021
# Epoch 55/500, Test Accuracy: 0.8980
# Epoch 56/500, Test Accuracy: 0.9026
# Epoch 57/500, Test Accuracy: 0.8985
# Epoch 58/500, Test Accuracy: 0.9029
# Epoch 59/500, Test Accuracy: 0.9040
# Epoch 60/500, Test Accuracy: 0.9007
# Epoch 61/500, Test Accuracy: 0.9014
# Epoch 62/500, Test Accuracy: 0.9030
# Epoch 63/500, Test Accuracy: 0.8955
# Epoch 64/500, Test Accuracy: 0.9000
# Epoch 65/500, Test Accuracy: 0.9008
# Epoch 66/500, Test Accuracy: 0.8965
# Epoch 67/500, Test Accuracy: 0.8924
# Epoch 68/500, Test Accuracy: 0.8988
# Epoch 69/500, Test Accuracy: 0.9040
# Epoch 70/500, Test Accuracy: 0.9011
# Epoch 71/500, Test Accuracy: 0.8994
# Epoch 72/500, Test Accuracy: 0.9035
# Epoch 73/500, Test Accuracy: 0.9004
# Epoch 74/500, Test Accuracy: 0.9025
# Epoch 75/500, Test Accuracy: 0.8998
# Epoch 76/500, Test Accuracy: 0.8981
# Epoch 77/500, Test Accuracy: 0.8979
# Epoch 78/500, Test Accuracy: 0.8958
# Epoch 79/500, Test Accuracy: 0.8983
# Epoch 80/500, Test Accuracy: 0.8970
# Epoch 81/500, Test Accuracy: 0.9014
# Epoch 82/500, Test Accuracy: 0.8988
# Epoch 83/500, Test Accuracy: 0.9008
# Epoch 84/500, Test Accuracy: 0.9028
# Epoch 85/500, Test Accuracy: 0.9015
# Epoch 86/500, Test Accuracy: 0.8989
# Epoch 87/500, Test Accuracy: 0.9007
# Epoch 88/500, Test Accuracy: 0.8987
# Epoch 89/500, Test Accuracy: 0.9000
# Epoch 90/500, Test Accuracy: 0.8997
# Epoch 91/500, Test Accuracy: 0.8965
# Epoch 92/500, Test Accuracy: 0.9008
# Epoch 93/500, Test Accuracy: 0.8966
# Epoch 94/500, Test Accuracy: 0.9025
# Epoch 95/500, Test Accuracy: 0.9015
# Epoch 96/500, Test Accuracy: 0.9048
# Epoch 97/500, Test Accuracy: 0.9027
# Epoch 98/500, Test Accuracy: 0.8981
# Epoch 99/500, Test Accuracy: 0.8984
# Epoch 100/500, Test Accuracy: 0.9006
# Epoch 101/500, Test Accuracy: 0.9042
# Epoch 102/500, Test Accuracy: 0.9060
# Epoch 103/500, Test Accuracy: 0.9053
# Epoch 104/500, Test Accuracy: 0.9034
# Epoch 105/500, Test Accuracy: 0.9058
# Epoch 106/500, Test Accuracy: 0.9042
# Epoch 107/500, Test Accuracy: 0.9064
# Epoch 108/500, Test Accuracy: 0.9068
# Epoch 109/500, Test Accuracy: 0.9057
# Epoch 110/500, Test Accuracy: 0.9024
# Epoch 111/500, Test Accuracy: 0.9089
# Epoch 112/500, Test Accuracy: 0.9075
# Epoch 113/500, Test Accuracy: 0.9021
# Epoch 114/500, Test Accuracy: 0.9042
# Epoch 115/500, Test Accuracy: 0.9052
# Epoch 116/500, Test Accuracy: 0.9071
# Epoch 117/500, Test Accuracy: 0.9050
# Epoch 118/500, Test Accuracy: 0.9046
# Epoch 119/500, Test Accuracy: 0.9059
# Epoch 120/500, Test Accuracy: 0.9067
# Epoch 1/10, Test Accuracy: 0.3000
# Epoch 2/10, Test Accuracy: 0.8232
# Epoch 3/10, Test Accuracy: 0.8268
# Epoch 4/10, Test Accuracy: 0.8298
# Epoch 5/10, Test Accuracy: 0.8356
# Epoch 6/10, Test Accuracy: 0.8310
# Epoch 7/10, Test Accuracy: 0.8340
# Epoch 8/10, Test Accuracy: 0.8352
# Epoch 9/10, Test Accuracy: 0.8486
# Epoch 10/10, Test Accuracy: 0.8424
# Epoch 1/10, Test Accuracy: 0.3742
# Epoch 2/10, Test Accuracy: 0.8078
# Epoch 3/10, Test Accuracy: 0.8256
# Epoch 4/10, Test Accuracy: 0.8248
# Epoch 5/10, Test Accuracy: 0.8360
# Epoch 6/10, Test Accuracy: 0.8328
# Epoch 7/10, Test Accuracy: 0.8308
# Epoch 8/10, Test Accuracy: 0.8472
# Epoch 9/10, Test Accuracy: 0.8444
# Epoch 10/10, Test Accuracy: 0.8450
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.5080
# Epoch 3/10, Test Accuracy: 0.8264
# Epoch 4/10, Test Accuracy: 0.8066
# Epoch 5/10, Test Accuracy: 0.8318
# Epoch 6/10, Test Accuracy: 0.8366
# Epoch 7/10, Test Accuracy: 0.8182
# Epoch 8/10, Test Accuracy: 0.8224
# Epoch 9/10, Test Accuracy: 0.8338
# Epoch 10/10, Test Accuracy: 0.8222
# Epoch 1/10, Test Accuracy: 0.5066
# Epoch 2/10, Test Accuracy: 0.7710
# Epoch 3/10, Test Accuracy: 0.7892
# Epoch 4/10, Test Accuracy: 0.8024
# Epoch 5/10, Test Accuracy: 0.8106
# Epoch 6/10, Test Accuracy: 0.8188
# Epoch 7/10, Test Accuracy: 0.8212
# Epoch 8/10, Test Accuracy: 0.8318
# Epoch 9/10, Test Accuracy: 0.8270
# Epoch 10/10, Test Accuracy: 0.8348
# Epoch 1/10, Test Accuracy: 0.0986
# Epoch 2/10, Test Accuracy: 0.4702
# Epoch 3/10, Test Accuracy: 0.7580
# Epoch 4/10, Test Accuracy: 0.7630
# Epoch 5/10, Test Accuracy: 0.7818
# Epoch 6/10, Test Accuracy: 0.7990
# Epoch 7/10, Test Accuracy: 0.8032
# Epoch 8/10, Test Accuracy: 0.8096
# Epoch 9/10, Test Accuracy: 0.8104
# Epoch 10/10, Test Accuracy: 0.8144
# Epoch 1/10, Test Accuracy: 0.7862
# Epoch 2/10, Test Accuracy: 0.8212
# Epoch 3/10, Test Accuracy: 0.8258
# Epoch 4/10, Test Accuracy: 0.8314
# Epoch 5/10, Test Accuracy: 0.8262
# Epoch 6/10, Test Accuracy: 0.8394
# Epoch 7/10, Test Accuracy: 0.8426
# Epoch 8/10, Test Accuracy: 0.8332
# Epoch 9/10, Test Accuracy: 0.8340
# Epoch 10/10, Test Accuracy: 0.8486
# Epoch 1/10, Test Accuracy: 0.3708
# Epoch 2/10, Test Accuracy: 0.8206
# Epoch 3/10, Test Accuracy: 0.8150
# Epoch 4/10, Test Accuracy: 0.8032
# Epoch 5/10, Test Accuracy: 0.8280
# Epoch 6/10, Test Accuracy: 0.8282
# Epoch 7/10, Test Accuracy: 0.8122
# Epoch 8/10, Test Accuracy: 0.8346
# Epoch 9/10, Test Accuracy: 0.8376
# Epoch 10/10, Test Accuracy: 0.8394
# Epoch 1/10, Test Accuracy: 0.5774
# Epoch 2/10, Test Accuracy: 0.7742
# Epoch 3/10, Test Accuracy: 0.7978
# Epoch 4/10, Test Accuracy: 0.8114
# Epoch 5/10, Test Accuracy: 0.8156
# Epoch 6/10, Test Accuracy: 0.8204
# Epoch 7/10, Test Accuracy: 0.8238
# Epoch 8/10, Test Accuracy: 0.8294
# Epoch 9/10, Test Accuracy: 0.8312
# Epoch 10/10, Test Accuracy: 0.8294
# Epoch 1/10, Test Accuracy: 0.4734
# Epoch 2/10, Test Accuracy: 0.8194
# Epoch 3/10, Test Accuracy: 0.8236
# Epoch 4/10, Test Accuracy: 0.8358
# Epoch 5/10, Test Accuracy: 0.8242
# Epoch 6/10, Test Accuracy: 0.8310
# Epoch 7/10, Test Accuracy: 0.8110
# Epoch 8/10, Test Accuracy: 0.8146
# Epoch 9/10, Test Accuracy: 0.8228
# Epoch 10/10, Test Accuracy: 0.8396
# Epoch 1/10, Test Accuracy: 0.2760
# Epoch 2/10, Test Accuracy: 0.8360
# Epoch 3/10, Test Accuracy: 0.8358
# Epoch 4/10, Test Accuracy: 0.8420
# Epoch 5/10, Test Accuracy: 0.8352
# Epoch 6/10, Test Accuracy: 0.8480
# Epoch 7/10, Test Accuracy: 0.8394
# Epoch 8/10, Test Accuracy: 0.8134
# Epoch 9/10, Test Accuracy: 0.8390
# Epoch 10/10, Test Accuracy: 0.8252
# Epoch 1/10, Test Accuracy: 0.3206
# Epoch 2/10, Test Accuracy: 0.8180
# Epoch 3/10, Test Accuracy: 0.8096
# Epoch 4/10, Test Accuracy: 0.8312
# Epoch 5/10, Test Accuracy: 0.8014
# Epoch 6/10, Test Accuracy: 0.7818
# Epoch 7/10, Test Accuracy: 0.8166
# Epoch 8/10, Test Accuracy: 0.8354
# Epoch 9/10, Test Accuracy: 0.8298
# Epoch 10/10, Test Accuracy: 0.7950
# Epoch 1/10, Test Accuracy: 0.3584
# Epoch 2/10, Test Accuracy: 0.7952
# Epoch 3/10, Test Accuracy: 0.8132
# Epoch 4/10, Test Accuracy: 0.8270
# Epoch 5/10, Test Accuracy: 0.8284
# Epoch 6/10, Test Accuracy: 0.8338
# Epoch 7/10, Test Accuracy: 0.8374
# Epoch 8/10, Test Accuracy: 0.8394
# Epoch 9/10, Test Accuracy: 0.8412
# Epoch 10/10, Test Accuracy: 0.8444
# Epoch 1/10, Test Accuracy: 0.3704
# Epoch 2/10, Test Accuracy: 0.8330
# Epoch 3/10, Test Accuracy: 0.8294
# Epoch 4/10, Test Accuracy: 0.8428
# Epoch 5/10, Test Accuracy: 0.8242
# Epoch 6/10, Test Accuracy: 0.8412
# Epoch 7/10, Test Accuracy: 0.8438
# Epoch 8/10, Test Accuracy: 0.8292
# Epoch 9/10, Test Accuracy: 0.8164
# Epoch 10/10, Test Accuracy: 0.8134
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.4312
# Epoch 3/10, Test Accuracy: 0.8378
# Epoch 4/10, Test Accuracy: 0.8160
# Epoch 5/10, Test Accuracy: 0.8436
# Epoch 6/10, Test Accuracy: 0.7856
# Epoch 7/10, Test Accuracy: 0.8420
# Epoch 8/10, Test Accuracy: 0.8106
# Epoch 9/10, Test Accuracy: 0.7998
# Epoch 10/10, Test Accuracy: 0.8200
# Epoch 1/10, Test Accuracy: 0.3248
# Epoch 2/10, Test Accuracy: 0.7976
# Epoch 3/10, Test Accuracy: 0.8232
# Epoch 4/10, Test Accuracy: 0.8346
# Epoch 5/10, Test Accuracy: 0.8382
# Epoch 6/10, Test Accuracy: 0.8440
# Epoch 7/10, Test Accuracy: 0.8462
# Epoch 8/10, Test Accuracy: 0.8468
# Epoch 9/10, Test Accuracy: 0.8472
# Epoch 10/10, Test Accuracy: 0.8436
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.4666
# Epoch 3/10, Test Accuracy: 0.8244
# Epoch 4/10, Test Accuracy: 0.8278
# Epoch 5/10, Test Accuracy: 0.8326
# Epoch 6/10, Test Accuracy: 0.8272
# Epoch 7/10, Test Accuracy: 0.8398
# Epoch 8/10, Test Accuracy: 0.8338
# Epoch 9/10, Test Accuracy: 0.8390
# Epoch 10/10, Test Accuracy: 0.8446
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.2952
# Epoch 3/10, Test Accuracy: 0.8068
# Epoch 4/10, Test Accuracy: 0.8360
# Epoch 5/10, Test Accuracy: 0.8412
# Epoch 6/10, Test Accuracy: 0.8304
# Epoch 7/10, Test Accuracy: 0.8404
# Epoch 8/10, Test Accuracy: 0.8332
# Epoch 9/10, Test Accuracy: 0.8222
# Epoch 10/10, Test Accuracy: 0.8406
# Epoch 1/10, Test Accuracy: 0.1822
# Epoch 2/10, Test Accuracy: 0.8022
# Epoch 3/10, Test Accuracy: 0.8252
# Epoch 4/10, Test Accuracy: 0.8358
# Epoch 5/10, Test Accuracy: 0.8064
# Epoch 6/10, Test Accuracy: 0.8102
# Epoch 7/10, Test Accuracy: 0.7810
# Epoch 8/10, Test Accuracy: 0.8410
# Epoch 9/10, Test Accuracy: 0.8242
# Epoch 10/10, Test Accuracy: 0.7774
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.2800
# Epoch 3/10, Test Accuracy: 0.7852
# Epoch 4/10, Test Accuracy: 0.7932
# Epoch 5/10, Test Accuracy: 0.8048
# Epoch 6/10, Test Accuracy: 0.8104
# Epoch 7/10, Test Accuracy: 0.8186
# Epoch 8/10, Test Accuracy: 0.8242
# Epoch 9/10, Test Accuracy: 0.8276
# Epoch 10/10, Test Accuracy: 0.8278
# Epoch 1/10, Test Accuracy: 0.3234
# Epoch 2/10, Test Accuracy: 0.7632
# Epoch 3/10, Test Accuracy: 0.7950
# Epoch 4/10, Test Accuracy: 0.8090
# Epoch 5/10, Test Accuracy: 0.8240
# Epoch 6/10, Test Accuracy: 0.8236
# Epoch 7/10, Test Accuracy: 0.8300
# Epoch 8/10, Test Accuracy: 0.8364
# Epoch 9/10, Test Accuracy: 0.8368
# Epoch 10/10, Test Accuracy: 0.8356
# Epoch 1/10, Test Accuracy: 0.8060
# Epoch 2/10, Test Accuracy: 0.8166
# Epoch 3/10, Test Accuracy: 0.8240
# Epoch 4/10, Test Accuracy: 0.8394
# Epoch 5/10, Test Accuracy: 0.8400
# Epoch 6/10, Test Accuracy: 0.8414
# Epoch 7/10, Test Accuracy: 0.8388
# Epoch 8/10, Test Accuracy: 0.8364
# Epoch 9/10, Test Accuracy: 0.8406
# Epoch 10/10, Test Accuracy: 0.8202
# Epoch 1/10, Test Accuracy: 0.8098
# Epoch 2/10, Test Accuracy: 0.8210
# Epoch 3/10, Test Accuracy: 0.8320
# Epoch 4/10, Test Accuracy: 0.8310
# Epoch 5/10, Test Accuracy: 0.8390
# Epoch 6/10, Test Accuracy: 0.8388
# Epoch 7/10, Test Accuracy: 0.8368
# Epoch 8/10, Test Accuracy: 0.8328
# Epoch 9/10, Test Accuracy: 0.8322
# Epoch 10/10, Test Accuracy: 0.8378
# Epoch 1/10, Test Accuracy: 0.4730
# Epoch 2/10, Test Accuracy: 0.7466
# Epoch 3/10, Test Accuracy: 0.7732
# Epoch 4/10, Test Accuracy: 0.7984
# Epoch 5/10, Test Accuracy: 0.8084
# Epoch 6/10, Test Accuracy: 0.8134
# Epoch 7/10, Test Accuracy: 0.8188
# Epoch 8/10, Test Accuracy: 0.8252
# Epoch 9/10, Test Accuracy: 0.8284
# Epoch 10/10, Test Accuracy: 0.8288
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.4270
# Epoch 3/10, Test Accuracy: 0.8244
# Epoch 4/10, Test Accuracy: 0.8318
# Epoch 5/10, Test Accuracy: 0.8346
# Epoch 6/10, Test Accuracy: 0.8430
# Epoch 7/10, Test Accuracy: 0.8246
# Epoch 8/10, Test Accuracy: 0.8370
# Epoch 9/10, Test Accuracy: 0.8294
# Epoch 10/10, Test Accuracy: 0.8520
# Epoch 1/10, Test Accuracy: 0.1012
# Epoch 2/10, Test Accuracy: 0.4822
# Epoch 3/10, Test Accuracy: 0.7872
# Epoch 4/10, Test Accuracy: 0.8078
# Epoch 5/10, Test Accuracy: 0.8162
# Epoch 6/10, Test Accuracy: 0.8208
# Epoch 7/10, Test Accuracy: 0.8278
# Epoch 8/10, Test Accuracy: 0.8298
# Epoch 9/10, Test Accuracy: 0.8364
# Epoch 10/10, Test Accuracy: 0.8346
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.4288
# Epoch 3/10, Test Accuracy: 0.8262
# Epoch 4/10, Test Accuracy: 0.8324
# Epoch 5/10, Test Accuracy: 0.8208
# Epoch 6/10, Test Accuracy: 0.8248
# Epoch 7/10, Test Accuracy: 0.8338
# Epoch 8/10, Test Accuracy: 0.8412
# Epoch 9/10, Test Accuracy: 0.8356
# Epoch 10/10, Test Accuracy: 0.8414
# Epoch 1/10, Test Accuracy: 0.3668
# Epoch 2/10, Test Accuracy: 0.8042
# Epoch 3/10, Test Accuracy: 0.8252
# Epoch 4/10, Test Accuracy: 0.8400
# Epoch 5/10, Test Accuracy: 0.8428
# Epoch 6/10, Test Accuracy: 0.8454
# Epoch 7/10, Test Accuracy: 0.8530
# Epoch 8/10, Test Accuracy: 0.8500
# Epoch 9/10, Test Accuracy: 0.8498
# Epoch 10/10, Test Accuracy: 0.8454
# Epoch 1/10, Test Accuracy: 0.2274
# Epoch 2/10, Test Accuracy: 0.5622
# Epoch 3/10, Test Accuracy: 0.7680
# Epoch 4/10, Test Accuracy: 0.7772
# Epoch 5/10, Test Accuracy: 0.7952
# Epoch 6/10, Test Accuracy: 0.8050
# Epoch 7/10, Test Accuracy: 0.8128
# Epoch 8/10, Test Accuracy: 0.8142
# Epoch 9/10, Test Accuracy: 0.8186
# Epoch 10/10, Test Accuracy: 0.8210
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.5230
# Epoch 3/10, Test Accuracy: 0.7816
# Epoch 4/10, Test Accuracy: 0.7912
# Epoch 5/10, Test Accuracy: 0.8030
# Epoch 6/10, Test Accuracy: 0.8092
# Epoch 7/10, Test Accuracy: 0.8162
# Epoch 8/10, Test Accuracy: 0.8230
# Epoch 9/10, Test Accuracy: 0.8240
# Epoch 10/10, Test Accuracy: 0.8336
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.3932
# Epoch 3/10, Test Accuracy: 0.8368
# Epoch 4/10, Test Accuracy: 0.8276
# Epoch 5/10, Test Accuracy: 0.8350
# Epoch 6/10, Test Accuracy: 0.8456
# Epoch 7/10, Test Accuracy: 0.8468
# Epoch 8/10, Test Accuracy: 0.8268
# Epoch 9/10, Test Accuracy: 0.8292
# Epoch 10/10, Test Accuracy: 0.8362
# Epoch 121/500, Test Accuracy: 0.9072
# Epoch 122/500, Test Accuracy: 0.9074
# Epoch 1/10, Test Accuracy: 0.8148
# Epoch 2/10, Test Accuracy: 0.8262
# Epoch 3/10, Test Accuracy: 0.8122
# Epoch 4/10, Test Accuracy: 0.8134
# Epoch 5/10, Test Accuracy: 0.8394
# Epoch 6/10, Test Accuracy: 0.8300
# Epoch 7/10, Test Accuracy: 0.8390
# Epoch 8/10, Test Accuracy: 0.8308
# Epoch 9/10, Test Accuracy: 0.8382
# Epoch 10/10, Test Accuracy: 0.8206
# Epoch 1/10, Test Accuracy: 0.1220
# Epoch 2/10, Test Accuracy: 0.4648
# Epoch 3/10, Test Accuracy: 0.8042
# Epoch 4/10, Test Accuracy: 0.8170
# Epoch 5/10, Test Accuracy: 0.8192
# Epoch 6/10, Test Accuracy: 0.8282
# Epoch 7/10, Test Accuracy: 0.8306
# Epoch 8/10, Test Accuracy: 0.8332
# Epoch 9/10, Test Accuracy: 0.8360
# Epoch 10/10, Test Accuracy: 0.8392
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.3332
# Epoch 3/10, Test Accuracy: 0.7902
# Epoch 4/10, Test Accuracy: 0.8064
# Epoch 5/10, Test Accuracy: 0.8216
# Epoch 6/10, Test Accuracy: 0.8310
# Epoch 7/10, Test Accuracy: 0.8316
# Epoch 8/10, Test Accuracy: 0.8364
# Epoch 9/10, Test Accuracy: 0.8344
# Epoch 10/10, Test Accuracy: 0.8378
# Epoch 1/10, Test Accuracy: 0.3882
# Epoch 2/10, Test Accuracy: 0.8318
# Epoch 3/10, Test Accuracy: 0.8186
# Epoch 4/10, Test Accuracy: 0.8326
# Epoch 5/10, Test Accuracy: 0.8396
# Epoch 6/10, Test Accuracy: 0.8306
# Epoch 7/10, Test Accuracy: 0.8470
# Epoch 8/10, Test Accuracy: 0.8290
# Epoch 9/10, Test Accuracy: 0.8462
# Epoch 10/10, Test Accuracy: 0.8268
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.5210
# Epoch 3/10, Test Accuracy: 0.8320
# Epoch 4/10, Test Accuracy: 0.8292
# Epoch 5/10, Test Accuracy: 0.8424
# Epoch 6/10, Test Accuracy: 0.8380
# Epoch 7/10, Test Accuracy: 0.8244
# Epoch 8/10, Test Accuracy: 0.8468
# Epoch 9/10, Test Accuracy: 0.8406
# Epoch 10/10, Test Accuracy: 0.8372
# Epoch 1/10, Test Accuracy: 0.1038
# Epoch 2/10, Test Accuracy: 0.2786
# Epoch 3/10, Test Accuracy: 0.7948
# Epoch 4/10, Test Accuracy: 0.8132
# Epoch 5/10, Test Accuracy: 0.8232
# Epoch 6/10, Test Accuracy: 0.8328
# Epoch 7/10, Test Accuracy: 0.8276
# Epoch 8/10, Test Accuracy: 0.8372
# Epoch 9/10, Test Accuracy: 0.8378
# Epoch 10/10, Test Accuracy: 0.8410
# Epoch 1/10, Test Accuracy: 0.1232
# Epoch 2/10, Test Accuracy: 0.4306
# Epoch 3/10, Test Accuracy: 0.7834
# Epoch 4/10, Test Accuracy: 0.8018
# Epoch 5/10, Test Accuracy: 0.8110
# Epoch 6/10, Test Accuracy: 0.8202
# Epoch 7/10, Test Accuracy: 0.8254
# Epoch 8/10, Test Accuracy: 0.8294
# Epoch 9/10, Test Accuracy: 0.8330
# Epoch 10/10, Test Accuracy: 0.8400
# Epoch 1/10, Test Accuracy: 0.3122
# Epoch 2/10, Test Accuracy: 0.8146
# Epoch 3/10, Test Accuracy: 0.8164
# Epoch 4/10, Test Accuracy: 0.8256
# Epoch 5/10, Test Accuracy: 0.8338
# Epoch 6/10, Test Accuracy: 0.8282
# Epoch 7/10, Test Accuracy: 0.8226
# Epoch 8/10, Test Accuracy: 0.8348
# Epoch 9/10, Test Accuracy: 0.8378
# Epoch 10/10, Test Accuracy: 0.8438
# Epoch 1/10, Test Accuracy: 0.1238
# Epoch 2/10, Test Accuracy: 0.4506
# Epoch 3/10, Test Accuracy: 0.8354
# Epoch 4/10, Test Accuracy: 0.8384
# Epoch 5/10, Test Accuracy: 0.8428
# Epoch 6/10, Test Accuracy: 0.8444
# Epoch 7/10, Test Accuracy: 0.8096
# Epoch 8/10, Test Accuracy: 0.8312
# Epoch 9/10, Test Accuracy: 0.8432
# Epoch 10/10, Test Accuracy: 0.8202
# Epoch 1/10, Test Accuracy: 0.3852
# Epoch 2/10, Test Accuracy: 0.8122
# Epoch 3/10, Test Accuracy: 0.8130
# Epoch 4/10, Test Accuracy: 0.8338
# Epoch 5/10, Test Accuracy: 0.8362
# Epoch 6/10, Test Accuracy: 0.8270
# Epoch 7/10, Test Accuracy: 0.8126
# Epoch 8/10, Test Accuracy: 0.8118
# Epoch 9/10, Test Accuracy: 0.8298
# Epoch 10/10, Test Accuracy: 0.8328
# Epoch 123/500, Test Accuracy: 0.9021
# Epoch 124/500, Test Accuracy: 0.9061
# Epoch 125/500, Test Accuracy: 0.9030
# Epoch 126/500, Test Accuracy: 0.9098
# Epoch 127/500, Test Accuracy: 0.9027
# Epoch 128/500, Test Accuracy: 0.9050
# Epoch 129/500, Test Accuracy: 0.9044
# Epoch 130/500, Test Accuracy: 0.9055
# Epoch 131/500, Test Accuracy: 0.9033
# Epoch 132/500, Test Accuracy: 0.9041
# Epoch 133/500, Test Accuracy: 0.9087
# Epoch 134/500, Test Accuracy: 0.9043
# Epoch 135/500, Test Accuracy: 0.9047
# Epoch 136/500, Test Accuracy: 0.9049
# Epoch 137/500, Test Accuracy: 0.9063
# Epoch 138/500, Test Accuracy: 0.9030
# Epoch 139/500, Test Accuracy: 0.9025
# Epoch 140/500, Test Accuracy: 0.9066
# Epoch 141/500, Test Accuracy: 0.9063
# Epoch 142/500, Test Accuracy: 0.9028
# Epoch 143/500, Test Accuracy: 0.9044
# Epoch 144/500, Test Accuracy: 0.9035
# Epoch 145/500, Test Accuracy: 0.9045
# Epoch 146/500, Test Accuracy: 0.9033
# Epoch 147/500, Test Accuracy: 0.9031
# Epoch 148/500, Test Accuracy: 0.8980
# Epoch 149/500, Test Accuracy: 0.9032
# Epoch 150/500, Test Accuracy: 0.9049
# Epoch 151/500, Test Accuracy: 0.9082
# Epoch 152/500, Test Accuracy: 0.9065
# Epoch 153/500, Test Accuracy: 0.9080
# Epoch 154/500, Test Accuracy: 0.9098
# Epoch 155/500, Test Accuracy: 0.9088
# Epoch 156/500, Test Accuracy: 0.9083
# Epoch 157/500, Test Accuracy: 0.9088
# Epoch 158/500, Test Accuracy: 0.9114
# Epoch 159/500, Test Accuracy: 0.9058
# Epoch 160/500, Test Accuracy: 0.9075
# Epoch 161/500, Test Accuracy: 0.9073
# Epoch 162/500, Test Accuracy: 0.9095
# Epoch 163/500, Test Accuracy: 0.9061
# Epoch 164/500, Test Accuracy: 0.9091
# Epoch 165/500, Test Accuracy: 0.9099
# Epoch 166/500, Test Accuracy: 0.9077
# Epoch 167/500, Test Accuracy: 0.9069
# Epoch 168/500, Test Accuracy: 0.9063
# Epoch 169/500, Test Accuracy: 0.9090
# Epoch 170/500, Test Accuracy: 0.9081
# Epoch 171/500, Test Accuracy: 0.9091
# Epoch 172/500, Test Accuracy: 0.9083
# Epoch 173/500, Test Accuracy: 0.9061
# Epoch 174/500, Test Accuracy: 0.9102
# Epoch 175/500, Test Accuracy: 0.9072
# Epoch 176/500, Test Accuracy: 0.9105
# Epoch 177/500, Test Accuracy: 0.9062
# Epoch 178/500, Test Accuracy: 0.9100
# Epoch 179/500, Test Accuracy: 0.9084
# Epoch 180/500, Test Accuracy: 0.9105
# Epoch 181/500, Test Accuracy: 0.9074
# Epoch 182/500, Test Accuracy: 0.9082
# Epoch 183/500, Test Accuracy: 0.9091
# Epoch 184/500, Test Accuracy: 0.9113
# Epoch 185/500, Test Accuracy: 0.9073
# Epoch 186/500, Test Accuracy: 0.9091
# Epoch 187/500, Test Accuracy: 0.9074
# Epoch 188/500, Test Accuracy: 0.9076
# Epoch 189/500, Test Accuracy: 0.9092
# Epoch 190/500, Test Accuracy: 0.9079
# Epoch 191/500, Test Accuracy: 0.9075
# Epoch 192/500, Test Accuracy: 0.9079
# Epoch 193/500, Test Accuracy: 0.9068
# Epoch 194/500, Test Accuracy: 0.9082
# Epoch 195/500, Test Accuracy: 0.9058
# Epoch 196/500, Test Accuracy: 0.9088
# Epoch 197/500, Test Accuracy: 0.9090
# Epoch 198/500, Test Accuracy: 0.9086
# Epoch 199/500, Test Accuracy: 0.9071
# Epoch 200/500, Test Accuracy: 0.9084
# Epoch 201/500, Test Accuracy: 0.9086
# Epoch 202/500, Test Accuracy: 0.9087
# Epoch 203/500, Test Accuracy: 0.9099
# Epoch 204/500, Test Accuracy: 0.9092
# Epoch 205/500, Test Accuracy: 0.9097
# Epoch 206/500, Test Accuracy: 0.9100
# Epoch 207/500, Test Accuracy: 0.9086
# Epoch 208/500, Test Accuracy: 0.9107
# Early stopping triggered.
# FashionMNIST Final Test Accuracy: 0.9114

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F
import numpy as np

# 손실 함수 정의
def Regularized_loss(model, n, y_pred, y_true, p=4, lam_margin=0.01, lam_l1=0.001, lam_l2=0.001):
    classification_loss = -torch.mean(y_true * torch.log_softmax(y_pred, dim=1))
    last_layer_weight = model.network[-1].weight
    RG_loss_margin = 1/n * torch.norm(
        last_layer_weight.unsqueeze(1) - last_layer_weight.unsqueeze(0), p=2, dim=2
    ).pow(p).sum()
    RG_loss_regularization = lam_l1 * torch.norm(last_layer_weight, p=1) + \
                             lam_l2 * torch.norm(last_layer_weight, p=2)
    RG_loss = lam_margin * RG_loss_margin + RG_loss_regularization
    loss = classification_loss + RG_loss
    return loss

# MLP 모델 정의
class MLP(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate=0.3):
        super(MLP, self).__init__()
        self.network = torch.nn.Sequential(
            torch.nn.Linear(input_dim, hidden_dim),
            torch.nn.BatchNorm1d(hidden_dim),
            torch.nn.LeakyReLU(negative_slope=0.01),  # LeakyReLU 사용
            torch.nn.Dropout(dropout_rate),
            torch.nn.Linear(hidden_dim, hidden_dim),
            torch.nn.BatchNorm1d(hidden_dim),
            torch.nn.LeakyReLU(negative_slope=0.01),  # LeakyReLU 사용
            torch.nn.Dropout(dropout_rate),
            torch.nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.network(x)

# 가중치 초기화 함수
def initialize_weights(m):
    if isinstance(m, torch.nn.Linear):
        torch.nn.init.kaiming_uniform_(m.weight, nonlinearity='leaky_relu')  # He 초기화

# Early Stopping 클래스 정의
class EarlyStoppingAccuracy:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_acc = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, current_acc):
        if self.best_acc is None:
            self.best_acc = current_acc
        elif current_acc - self.best_acc > self.min_delta:
            self.best_acc = current_acc
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

#  LeakyReLU를 사용한 학습 함수
def R_MLR_with_FashionMNIST(x_train, y_train, x_test, y_test, para):
    # Numpy 데이터를 PyTorch Tensor로 변환 및 정규화
    x_train = x_train.astype(np.float32) / 255.0
    x_test = x_test.astype(np.float32) / 255.0
    x_train = x_train.reshape(-1, 28 * 28)
    x_test = x_test.reshape(-1, 28 * 28)

    # 라벨을 Tensor로 변환
    y_train = torch.tensor(y_train, dtype=torch.long)
    y_test = torch.tensor(y_test, dtype=torch.long)

    # 데이터셋 생성
    train_dataset = TensorDataset(torch.tensor(x_train), y_train)
    test_dataset = TensorDataset(torch.tensor(x_test), y_test)

    # DataLoader 생성
    train_loader = DataLoader(train_dataset, batch_size=para["batch_size"], shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=para["batch_size"], shuffle=False)

    # MLP 모델 초기화
    input_dim = 28 * 28
    hidden_dim = para.get("hidden_dim", 512)
    dropout_rate = para.get("dropout_rate", 0.3)
    model = MLP(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=10, dropout_rate=dropout_rate)
    model.apply(initialize_weights)

    # 옵티마이저와 학습 스케줄러 설정
    optimizer = torch.optim.Adam(model.parameters(), lr=para["lr"], weight_decay=para["weight_decay"])
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

    # Early Stopping 설정
    early_stopping = EarlyStoppingAccuracy(patience=para["patience"], min_delta=para["min_delta"])

    # 학습 루프
    for epoch in range(para["num_epoch"]):
        model.train()
        for X_batch, y_batch in train_loader:
            y_pred = model(X_batch)
            y_onehot = F.one_hot(y_batch, num_classes=10).float()
            loss = Regularized_loss(model, len(x_train), y_pred, y_onehot, para["p"], para["lam_margin"], para["lam_l1"], para["lam_l2"])
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        scheduler.step()

        # 평가
        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                y_pred = model(X_batch)
                correct += (torch.argmax(y_pred, dim=1) == y_batch).sum().item()
                total += y_batch.size(0)

            test_acc = correct / total
            print(f"Epoch {epoch + 1}/{para['num_epoch']}, Test Accuracy: {test_acc:.4f}")

            # Early stopping
            early_stopping(test_acc)
            if early_stopping.early_stop:
                print("Early stopping triggered.")
                break

    return early_stopping.best_acc

# Best Accuray 최적화 결과의 파라미터 사용 
fashion_params = {
    "num_epoch": 500,
    "lr": 0.0005,
    "weight_decay": 1e-4,
    "lam_margin": 0.01,
    "lam_l1": 0.001,
    "lam_l2": 0.001,
    "p": 4,
    "patience": 50,
    "min_delta": 1e-4,
    "batch_size": 128,
    "hidden_dim": 512,
    "dropout_rate": 0.3
}

# 학습 실행
final_accuracy = R_MLR_with_FashionMNIST(x_train, y_train, x_test, y_test, fashion_params)
print(f"FashionMNIST Final Test Accuracy: {final_accuracy:.4f}")
# Out:
# Epoch 1/500, Test Accuracy: 0.8554
# Epoch 2/500, Test Accuracy: 0.8653
# Epoch 3/500, Test Accuracy: 0.8720
# Epoch 4/500, Test Accuracy: 0.8630
# Epoch 5/500, Test Accuracy: 0.8770
# Epoch 6/500, Test Accuracy: 0.8776
# Epoch 7/500, Test Accuracy: 0.8669
# Epoch 8/500, Test Accuracy: 0.8797
# Epoch 9/500, Test Accuracy: 0.8859
# Epoch 10/500, Test Accuracy: 0.8806
# Epoch 11/500, Test Accuracy: 0.8859
# Epoch 12/500, Test Accuracy: 0.8893
# Epoch 13/500, Test Accuracy: 0.8874
# Epoch 14/500, Test Accuracy: 0.8903
# Epoch 15/500, Test Accuracy: 0.8911
# Epoch 16/500, Test Accuracy: 0.8853
# Epoch 17/500, Test Accuracy: 0.8901
# Epoch 18/500, Test Accuracy: 0.8881
# Epoch 19/500, Test Accuracy: 0.8772
# Epoch 20/500, Test Accuracy: 0.8872
# Epoch 21/500, Test Accuracy: 0.8899
# Epoch 22/500, Test Accuracy: 0.8880
# Epoch 23/500, Test Accuracy: 0.8778
# Epoch 24/500, Test Accuracy: 0.8564
# Epoch 25/500, Test Accuracy: 0.8908
# Epoch 26/500, Test Accuracy: 0.8927
# Epoch 27/500, Test Accuracy: 0.8873
# Epoch 28/500, Test Accuracy: 0.8910
# Epoch 29/500, Test Accuracy: 0.8837
# Epoch 30/500, Test Accuracy: 0.8890
# Epoch 31/500, Test Accuracy: 0.8933
# Epoch 32/500, Test Accuracy: 0.8992
# Epoch 33/500, Test Accuracy: 0.8741
# Epoch 34/500, Test Accuracy: 0.8910
# Epoch 35/500, Test Accuracy: 0.8907
# Epoch 36/500, Test Accuracy: 0.8794
# Epoch 37/500, Test Accuracy: 0.8938
# Epoch 38/500, Test Accuracy: 0.8908
# Epoch 39/500, Test Accuracy: 0.8876
# Epoch 40/500, Test Accuracy: 0.8870
# Epoch 41/500, Test Accuracy: 0.8954
# Epoch 42/500, Test Accuracy: 0.8939
# Epoch 43/500, Test Accuracy: 0.8918
# Epoch 44/500, Test Accuracy: 0.8928
# Epoch 45/500, Test Accuracy: 0.8940
# Epoch 46/500, Test Accuracy: 0.8911
# Epoch 47/500, Test Accuracy: 0.8935
# Epoch 48/500, Test Accuracy: 0.8861
# Epoch 49/500, Test Accuracy: 0.8890
# Epoch 50/500, Test Accuracy: 0.8852
# Epoch 51/500, Test Accuracy: 0.9036
# Epoch 52/500, Test Accuracy: 0.9006
# Epoch 53/500, Test Accuracy: 0.9027
# Epoch 54/500, Test Accuracy: 0.8964
# Epoch 55/500, Test Accuracy: 0.8972
# Epoch 56/500, Test Accuracy: 0.8983
# Epoch 57/500, Test Accuracy: 0.9018
# Epoch 58/500, Test Accuracy: 0.9026
# Epoch 59/500, Test Accuracy: 0.8975
# Epoch 60/500, Test Accuracy: 0.9001
# Epoch 61/500, Test Accuracy: 0.8921
# Epoch 62/500, Test Accuracy: 0.9021
# Epoch 63/500, Test Accuracy: 0.9013
# Epoch 64/500, Test Accuracy: 0.9004
# Epoch 65/500, Test Accuracy: 0.8981
# Epoch 66/500, Test Accuracy: 0.8999
# Epoch 67/500, Test Accuracy: 0.9018
# Epoch 68/500, Test Accuracy: 0.9024
# Epoch 69/500, Test Accuracy: 0.8947
# Epoch 70/500, Test Accuracy: 0.8980
# Epoch 71/500, Test Accuracy: 0.8861
# Epoch 72/500, Test Accuracy: 0.9011
# Epoch 73/500, Test Accuracy: 0.8985
# Epoch 74/500, Test Accuracy: 0.8879
# Epoch 75/500, Test Accuracy: 0.8972
# Epoch 76/500, Test Accuracy: 0.8963
# Epoch 77/500, Test Accuracy: 0.8998
# Epoch 78/500, Test Accuracy: 0.8915
# Epoch 79/500, Test Accuracy: 0.9004
# Epoch 80/500, Test Accuracy: 0.8961
# Epoch 81/500, Test Accuracy: 0.8990
# Epoch 82/500, Test Accuracy: 0.8923
# Epoch 83/500, Test Accuracy: 0.9000
# Epoch 84/500, Test Accuracy: 0.9017
# Epoch 85/500, Test Accuracy: 0.9025
# Epoch 86/500, Test Accuracy: 0.8929
# Epoch 87/500, Test Accuracy: 0.8996
# Epoch 88/500, Test Accuracy: 0.8949
# Epoch 89/500, Test Accuracy: 0.8980
# Epoch 90/500, Test Accuracy: 0.8926
# Epoch 91/500, Test Accuracy: 0.8859
# Epoch 92/500, Test Accuracy: 0.9013
# Epoch 93/500, Test Accuracy: 0.8976
# Epoch 94/500, Test Accuracy: 0.9048
# Epoch 95/500, Test Accuracy: 0.8985
# Epoch 96/500, Test Accuracy: 0.8990
# Epoch 97/500, Test Accuracy: 0.8963
# Epoch 98/500, Test Accuracy: 0.8995
# Epoch 99/500, Test Accuracy: 0.8949
# Epoch 100/500, Test Accuracy: 0.8959
# Epoch 101/500, Test Accuracy: 0.9039
# Epoch 102/500, Test Accuracy: 0.9019
# Epoch 103/500, Test Accuracy: 0.9044
# Epoch 104/500, Test Accuracy: 0.9067
# Epoch 105/500, Test Accuracy: 0.8983
# Epoch 106/500, Test Accuracy: 0.9015
# Epoch 107/500, Test Accuracy: 0.9051
# Epoch 108/500, Test Accuracy: 0.9034
# Epoch 109/500, Test Accuracy: 0.9022
# Epoch 110/500, Test Accuracy: 0.9039
# Epoch 111/500, Test Accuracy: 0.9016
# Epoch 112/500, Test Accuracy: 0.9017
# Epoch 113/500, Test Accuracy: 0.8959
# Epoch 114/500, Test Accuracy: 0.8971
# Epoch 115/500, Test Accuracy: 0.9002
# Epoch 116/500, Test Accuracy: 0.9029
# Epoch 117/500, Test Accuracy: 0.9023
# Epoch 118/500, Test Accuracy: 0.9006
# Epoch 119/500, Test Accuracy: 0.9023
# Epoch 120/500, Test Accuracy: 0.9022
# Epoch 121/500, Test Accuracy: 0.8991
# Epoch 122/500, Test Accuracy: 0.9005
# Epoch 123/500, Test Accuracy: 0.9037
# Epoch 124/500, Test Accuracy: 0.9003
# Epoch 125/500, Test Accuracy: 0.8980
# Epoch 126/500, Test Accuracy: 0.9016
# Epoch 127/500, Test Accuracy: 0.8957
# Epoch 128/500, Test Accuracy: 0.9013
# Epoch 129/500, Test Accuracy: 0.9020
# Epoch 130/500, Test Accuracy: 0.9006
# Epoch 131/500, Test Accuracy: 0.8999
# Epoch 132/500, Test Accuracy: 0.9060
# Epoch 133/500, Test Accuracy: 0.9007
# Epoch 134/500, Test Accuracy: 0.9023
# Epoch 135/500, Test Accuracy: 0.8996
# Epoch 136/500, Test Accuracy: 0.9047
# Epoch 137/500, Test Accuracy: 0.9046
# Epoch 138/500, Test Accuracy: 0.9024
# Epoch 139/500, Test Accuracy: 0.9013
# Epoch 140/500, Test Accuracy: 0.8990
# Epoch 141/500, Test Accuracy: 0.8990
# Epoch 142/500, Test Accuracy: 0.8976
# Epoch 143/500, Test Accuracy: 0.9001
# Epoch 144/500, Test Accuracy: 0.9012
# Epoch 145/500, Test Accuracy: 0.9001
# Epoch 146/500, Test Accuracy: 0.8969
# Epoch 147/500, Test Accuracy: 0.9033
# Epoch 148/500, Test Accuracy: 0.9021
# Epoch 149/500, Test Accuracy: 0.8988
# Epoch 150/500, Test Accuracy: 0.8981
# Epoch 151/500, Test Accuracy: 0.9064
# Epoch 152/500, Test Accuracy: 0.9030
# Epoch 153/500, Test Accuracy: 0.9072
# Epoch 154/500, Test Accuracy: 0.9020
# Epoch 155/500, Test Accuracy: 0.9027
# Epoch 156/500, Test Accuracy: 0.9043
# Epoch 157/500, Test Accuracy: 0.9038
# Epoch 158/500, Test Accuracy: 0.9022
# Epoch 159/500, Test Accuracy: 0.9039
# Epoch 160/500, Test Accuracy: 0.9043
# Epoch 161/500, Test Accuracy: 0.9043
# Epoch 162/500, Test Accuracy: 0.9011
# Epoch 163/500, Test Accuracy: 0.9050
# Epoch 164/500, Test Accuracy: 0.9032
# Epoch 165/500, Test Accuracy: 0.9026
# Epoch 166/500, Test Accuracy: 0.9031
# Epoch 167/500, Test Accuracy: 0.9039
# Epoch 168/500, Test Accuracy: 0.9052
# Epoch 169/500, Test Accuracy: 0.9057
# Epoch 170/500, Test Accuracy: 0.9015
# Epoch 171/500, Test Accuracy: 0.9041
# Epoch 172/500, Test Accuracy: 0.9022
# Epoch 173/500, Test Accuracy: 0.9047
# Epoch 174/500, Test Accuracy: 0.9056
# Epoch 175/500, Test Accuracy: 0.9042
# Epoch 176/500, Test Accuracy: 0.9034
# Epoch 177/500, Test Accuracy: 0.9032
# Epoch 178/500, Test Accuracy: 0.9041
# Epoch 179/500, Test Accuracy: 0.9027
# Epoch 180/500, Test Accuracy: 0.9037
# Epoch 181/500, Test Accuracy: 0.9030
# Epoch 182/500, Test Accuracy: 0.9026
# Epoch 183/500, Test Accuracy: 0.9061
# Epoch 184/500, Test Accuracy: 0.9032
# Epoch 185/500, Test Accuracy: 0.9043
# Epoch 186/500, Test Accuracy: 0.9025
# Epoch 187/500, Test Accuracy: 0.9018
# Epoch 188/500, Test Accuracy: 0.9035
# Epoch 189/500, Test Accuracy: 0.9036
# Epoch 190/500, Test Accuracy: 0.9051
# Epoch 191/500, Test Accuracy: 0.9056
# Epoch 192/500, Test Accuracy: 0.9023
# Epoch 193/500, Test Accuracy: 0.9038
# Epoch 194/500, Test Accuracy: 0.9037
# Epoch 195/500, Test Accuracy: 0.9011
# Epoch 196/500, Test Accuracy: 0.9035
# Epoch 197/500, Test Accuracy: 0.9054
# Epoch 198/500, Test Accuracy: 0.9032
# Epoch 199/500, Test Accuracy: 0.9025
# Epoch 200/500, Test Accuracy: 0.9035
# Epoch 201/500, Test Accuracy: 0.9041
# Epoch 202/500, Test Accuracy: 0.9070
# Epoch 203/500, Test Accuracy: 0.9069
# Early stopping triggered.
# FashionMNIST Final Test Accuracy: 0.9072
